# %% [markdown]
# <a href="https://colab.research.google.com/github/jjlopezal/Ergonautas/blob/main/R66.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import xlrd
from google.colab import files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_r66 = '/content/drive/MyDrive/R37/df_R66.csv'
df_r66= pd.read_csv(data_r66)
df_r66.head(50)
# Out:
#     Year                                         occupation occupation_code  \
# 0   2017                                    All Occupations             NaN
# 1   2017  Management, Business, Science, and Arts Occupa...             NaN
# 2   2017    Management, Business, and Financial Occupations             NaN
# 3   2017                             Management Occupations        110000.0
# 4   2017                                     Top Executives        111000.0
# 5   2017                                   Chief Executives        111010.0
# 6   2017                                   Chief Executives        111011.0
# 7   2017                    General and Operations Managers        111020.0
# 8   2017                    General and Operations Managers        111021.0
# 9   2017  Advertising, Marketing, Promotions, Public Rel...        112000.0
# 10  2017                Advertising and Promotions Managers        112010.0
# ...

# %%
df_r66['cases']=pd.to_numeric(df_r66.cases, errors='coerce')

df_r66.dtypes
# Out:
# Year                 int64
# occupation          object
# occupation_code     object
# industry           float64
# naics_code         float64
# age_group          float64
# days_away           object
# cases              float64
# total_cases         object
# median_days         object
# dtype: object

# %%
df_r66_sistemas = df_r66[(df_r66.occupation_code=='113020.0') | (df_r66.occupation_code=='151131.0')|
                    (df_r66.occupation_code=='113021.0') | (df_r66.occupation_code=='151130.0')|
                    (df_r66.occupation_code=='150000.0') | (df_r66.occupation_code=='151121.0')|
                    (df_r66.occupation_code=='151100.0') | (df_r66.occupation_code=='151120.0')|
                    (df_r66.occupation_code=='151132.0') | (df_r66.occupation_code=='151133.0')|
                    (df_r66.occupation_code=='151140.0') | (df_r66.occupation_code=='151142.0')|
                    (df_r66.occupation_code=='151143.0') | (df_r66.occupation_code=='151150.0')|
                    (df_r66.occupation_code=='151151.0') | (df_r66.occupation_code=='151152.0')|
                    (df_r66.occupation_code=='151190.0') | (df_r66.occupation_code=='151199.0')]
df_r66_sistemas
# Out:
#       Year                                 occupation occupation_code  \
# 20    2017  Computer and Information Systems Managers        113020.0
# 21    2017  Computer and Information Systems Managers        113021.0
# 111   2017      Computer and Mathematical Occupations        150000.0
# 112   2017                       Computer Occupations        151100.0
# 113   2017          Computer and Information Analysts        151120.0
# ...    ...                                        ...             ...
# 6836  2017               Computer Support Specialists        151150.0
# 6837  2017          Computer User Support Specialists        151151.0
# 6838  2017       Computer Network Support Specialists        151152.0
# 6839  2017         Miscellaneous Computer Occupations        151190.0
# 6840  2017            Computer Occupations, All Other        151199.0
#
#       industry  naics_code  age_group        days_away  cases total_cases  \
# ...

# %%
df_r66_sistemas.to_csv('df_R66_sistemas.csv', index= False)

# %%
df_r66.to_csv('df_R66_cambiado.csv', index= False)
